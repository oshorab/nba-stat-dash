# %%
import pandas as pd

# %%
df = pd.read_excel('kobe_AdjShoot.xls')

# %%
df
# Out:
#      Season  Age   Tm   Lg Pos   G    MP     FG     2P     3P  ...    FTr  \
# 0   1996-97   18  LAL  NBA  SF  71  1103  0.417  0.437  0.375  ...  0.393
# 1   1997-98   19  LAL  NBA  SF  79  2056  0.428  0.456  0.341  ...  0.501
# 2   1998-99   20  LAL  NBA  SG  50  1896  0.465  0.494  0.267  ...  0.375
# 3   1999-00   21  LAL  NBA  SG  66  2524  0.468  0.489  0.319  ...  0.341
# 4   2000-01   22  LAL  NBA  SG  68  2783  0.464  0.489  0.305  ...  0.369
# 5   2001-02   23  LAL  NBA  SG  80  3063  0.469  0.489  0.250  ...  0.369
# 6   2002-03   24  LAL  NBA  SG  82  3401  0.451  0.465  0.383  ...  0.371
# 7   2003-04   25  LAL  NBA  SG  65  2447  0.438  0.463  0.327  ...  0.452
# 8   2004-05   26  LAL  NBA  SG  66  2689  0.433  0.472  0.339  ...  0.502
# 9   2005-06   27  LAL  NBA  SG  80  3277  0.450  0.482  0.347  ...  0.377
# 10  2006-07   28  LAL  NBA  SG  77  3140  0.463  0.497  0.344  ...  0.437
# 11  2007-08   29  LAL  NBA  SG  82  3192  0.459  0.490  0.361  ...  0.439
# ...

# %%
df2 = df[["Season","Age","FG.1", "2P.1","3P.1", "eFG.1", "FT.1", "TS.1"]]

# %%
df2
# Out:
#      Season  Age   FG.1   2P.1   3P.1  eFG.1   FT.1   TS.1
# 0   2003-04   19  0.439  0.460  0.347  0.471  0.752  0.516
# 1   2004-05   20  0.447  0.470  0.356  0.482  0.756  0.529
# 2   2005-06   21  0.454  0.478  0.358  0.490  0.745  0.536
# 3   2006-07   22  0.458  0.485  0.358  0.496  0.752  0.541
# 4   2007-08   23  0.457  0.484  0.362  0.497  0.755  0.540
# 5   2008-09   24  0.459  0.485  0.367  0.500  0.771  0.544
# 6   2009-10   25  0.461  0.492  0.355  0.501  0.759  0.543
# 7   2010-11   26  0.459  0.487  0.358  0.498  0.763  0.541
# 8   2011-12   27  0.448  0.477  0.349  0.487  0.752  0.527
# 9   2012-13   28  0.453  0.483  0.359  0.496  0.753  0.535
# 10  2013-14   29  0.454  0.488  0.360  0.501  0.756  0.541
# 11  2014-15   30  0.449  0.485  0.350  0.496  0.750  0.534
# 12  2015-16   31  0.452  0.491  0.354  0.502  0.757  0.541
# 13  2016-17   32  0.457  0.503  0.358  0.514  0.772  0.552
# 14  2017-18   33  0.460  0.510  0.362  0.521  0.767  0.556
# ...

# %%
df2[df2["Season"] == '2003-04'].values.tolist()[0][2:]
# Out:
# [0.439, 0.46, 0.347, 0.471, 0.752, 0.516]

# %%
df2.columns.values.tolist()[2:]
# Out:
# ['FG.1', '2P.1', '3P.1', 'eFG.1', 'FT.1', 'TS.1']

# %%
df.columns.values.tolist()[]
# Out:
# ['FG', '2P', '3P', 'eFG', 'FT', 'TS']
